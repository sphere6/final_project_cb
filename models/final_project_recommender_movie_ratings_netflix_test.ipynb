# %% [markdown]
# # RECOMMENDER MOVIE RATINGS TEST

# %%
import numpy as np
import pandas as pd
from surprise import SVD
from surprise import NormalPredictor
from surprise.model_selection import cross_validate
from surprise.model_selection import KFold
from surprise.model_selection import GridSearchCV
from surprise import Dataset, Reader,accuracy
from surprise import get_dataset_dir, dump
from surprise.model_selection import train_test_split
from surprise import KNNBaseline

# %%
#Movie information
mv_info = pd.read_csv('../input/dataset/movie_titles.csv',error_bad_lines=False, header=None, names = ['MovieID','YearOfRelease','Title'])
mv_info['YearOfRelease'] = mv_info['YearOfRelease'].fillna(0).astype(int)

#Movie Ratings Subset from data preparation Netflix file
mv_ss = pd.read_csv('../input/dataset-balanced/movies_subset_balanced.csv')
mv_ss['RatingDate'] = pd.to_datetime(mv_ss['RatingDate'])
mv_ss['MovieID'] = mv_ss['MovieID'].astype(int)
mv_ss['UserID'] = mv_ss['UserID'].astype(int)
mv_ss_full = mv_ss.merge(mv_info, left_on = 'MovieID', right_on = 'MovieID')
mv_ss_full['RatingDate'] = pd.to_datetime(mv_ss_full['RatingDate'])
mv_ss['MovieID'] = mv_ss['MovieID'].astype(int)
mv_ss['UserID'] = mv_ss['UserID'].astype(int)

# %%
mv_ss_full.head()
# Out:
#    MovieID   UserID  Rating RatingDate  YearOfRelease                   Title
# 0       30  1366162       1 2005-10-26           2003  Something's Gotta Give
# 1       30   483101       1 2005-07-07           2003  Something's Gotta Give
# 2       30  2148796       1 2004-11-20           2003  Something's Gotta Give
# 3       30   998271       1 2004-06-21           2003  Something's Gotta Give
# 4       30   607621       1 2005-06-07           2003  Something's Gotta Give

# %%
mv_ss_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250000 entries, 0 to 249999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   MovieID        250000 non-null  int64
#  1   UserID         250000 non-null  int64
#  2   Rating         250000 non-null  int64
#  3   RatingDate     250000 non-null  datetime64[ns]
#  4   YearOfRelease  250000 non-null  int64
#  5   Title          250000 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 13.4+ MB

# %%
mv_info.head()
# Out:
#    MovieID  YearOfRelease                         Title
# 0        1           2003               Dinosaur Planet
# 1        2           2004    Isle of Man TT 2004 Review
# 2        3           1997                     Character
# 3        4           1994  Paula Abdul's Get Up & Dance
# 4        5           2004      The Rise and Fall of ECW

# %%
mv_ss.head()
# Out:
#    MovieID   UserID  Rating RatingDate
# 0       30  1366162       1 2005-10-26
# 1       30   483101       1 2005-07-07
# 2       30  2148796       1 2004-11-20
# 3       30   998271       1 2004-06-21
# 4       30   607621       1 2005-06-07

# %%
pd.set_option('display.max_rows', None)
movies_tot = mv_ss_full.groupby(['Title', 'MovieID']).count().reset_index()[['Title', 'MovieID']]
movies_tot
# Out:
#                                                  Title  MovieID
# 0                                       13 Going on 30    16082
# 1                                       50 First Dates     1962
# 2                                     A Beautiful Mind     1180
# 3                                       A Few Good Men    16668
# 4                                        About Schmidt     3756
# 5                                           Adaptation    12084
# 6                                        Air Force One    13651
# 7                                     Along Came Polly     2391
# 8                                  Along Came a Spider    12299
# 9                                      American Beauty      571
# 10                                        American Pie    11337
# 11               Anchorman: The Legend of Ron Burgundy     7635
# 12                                    Anger Management    16882
# 13                                           Apollo 13     7745
# 14                                          Armageddon     6972
# 15                                Being John Malkovich     2122
# 16                                Bend It Like Beckham     1470
# 17                                                 Big    15755
# 18                                           Big Daddy    15393
# 19                                            Big Fish    12161
# 20                                          Braveheart     2782
# 21                             Bringing Down the House     4745
# 22                                      Bruce Almighty     3860
# 23                                 Catch Me If You Can     8644
# 24                                Cheaper by the Dozen     6859
# 25                                             Chicago    13359
# 26                            Clear and Present Danger    16128
# 27                                       Cold Mountain    10550
# 28                                          Collateral     6134
# 29                                   Coming to America    12343
# 30                                             Con Air    16242
# 31                                  Dead Poets Society    14928
# 32                                            Die Hard     9960
# 33                                       Dirty Dancing     7617
# 34                    Dodgeball: A True Underdog Story     5401
# 35                                     Double Jeopardy    12911
# 36                                  Enemy of the State    14149
# 37                                          Entrapment     6692
# 38                                     Erin Brockovich     4656
# 39               Eternal Sunshine of the Spotless Mind     1865
# 40                                            Face/Off    16765
# 41                                     Fahrenheit 9/11    11022
# 42                                 Father of the Bride    16139
# 43                            Ferris Bueller's Day Off     6971
# 44                                          Fight Club     5926
# 45                           Finding Nemo (Widescreen)     3962
# 46                                   Finding Neverland     2913
# 47                                        Forrest Gump    11283
# 48                                   Gangs of New York    10730
# 49                                        Garden State     3917
# 50                                               Ghost     3106
# 51                                        Ghostbusters    17560
# 52                                           Gladiator    13728
# 53                                  Gone in 60 Seconds     4996
# 54                                   Good Will Hunting     8904
# 55                         GoodFellas: Special Edition     5732
# 56                                              Grease    15062
# 57                                       Happy Gilmore     8764
# 58             Harry Potter and the Chamber of Secrets    11443
# 59            Harry Potter and the Prisoner of Azkaban    12338
# 60               Harry Potter and the Sorcerer's Stone    17627
# 61                                             Hidalgo    12732
# 62                                               Hitch    17324
# 63                                        Hotel Rwanda    11607
# 64                        How to Lose a Guy in 10 Days    14538
# 65                                                   I     5496
# 66                                    Independence Day    15124
# 67                  Indiana Jones and the Last Crusade    16954
# 68                Indiana Jones and the Temple of Doom    11781
# 69                                       Jerry Maguire    13763
# 70                                              John Q    12672
# 71                                       Jurassic Park    14312
# 72                                   Kill Bill: Vol. 1    14454
# 73                                   Kill Bill: Vol. 2      457
# 74                                      Legally Blonde    17308
# 75                                       Lethal Weapon     1798
# 76                                     Lethal Weapon 4    14367
# 77       Lord of the Rings: The Fellowship of the Ring     2452
# 78           Lord of the Rings: The Return of the King    14240
# 79                   Lord of the Rings: The Two Towers    11521
# 80                                 Lost in Translation    12232
# 81                                       Love Actually     4472
# 82                                   Maid in Manhattan    11149
# 83                                         Man on Fire     1220
# 84     Master and Commander: The Far Side of the World    11182
# 85                                      Matchstick Men    15788
# 86                                          Mean Girls      758
# 87                                    Meet the Fockers    11077
# 88                                    Meet the Parents    17088
# 89                                             Memento     5862
# 90                                        Men in Black    12918
# 91                                     Men in Black II     3427
# 92                                        Men of Honor     7234
# 93                                 Million Dollar Baby    11812
# 94                                     Minority Report     8387
# 95                                   Miss Congeniality     5317
# 96                                 Mission: Impossible     5054
# 97                                     Mona Lisa Smile    15563
# 98                                             Monster    14999
# 99                                      Monster's Ball     7281
# 100                                           Monsters    11089
# 101                                          Mr. Deeds     9756
# 102                           My Big Fat Greek Wedding     6206
# 103                                       Mystic River    12582
# 104                                  Napoleon Dynamite     3151
# 105                                  National Treasure    17169
# 106                                     Ocean's Eleven    15107
# 107                                     Ocean's Twelve    10358
# 108                                        Patch Adams     4123
# 109                                     Pay It Forward      313
# 110                                           Paycheck     4972
# 111                                       Pearl Harbor     9340
# 112                                       Philadelphia    17154
# 113                                        Phone Booth    15471
# 114  Pirates of the Caribbean: The Curse of the Bla...     1905
# 115                                       Pretty Woman     6287
# 116                                       Pulp Fiction    11064
# 117                                              Radio    11040
# 118                            Raiders of the Lost Ark    10042
# 119                                           Rain Man     4640
# 120                                                Ray      886
# 121                                Remember the Titans    15844
# 122                                     Reservoir Dogs      175
# 123                                  Road to Perdition     4356
# 124                                      Runaway Bride    10359
# 125                                       Runaway Jury     4951
# 126                                           S.W.A.T.     1307
# 127                                Saving Private Ryan    17157
# 128                                   Schindler's List    12870
# 129                                         Seabiscuit     5085
# 130                                   Secondhand Lions     1110
# 131                                              Seven     8596
# 132                                Shrek (Full-screen)    14621
# 133                                            Shrek 2     3938
# 134                                           Sideways     3282
# 135                                              Signs     4043
# 136                                         Sister Act     6386
# 137                               Sleepless in Seattle     1542
# 138                             Something's Gotta Give       30
# 139                                          Spanglish     6475
# 140                                              Speed      607
# 141                                         Spider-Man    14410
# 142                                       Spider-Man 2    12155
# 143        Star Wars: Episode II: Attack of the Clones     8687
# 144      Star Wars: Episode V: The Empire Strikes Back     5582
# 145                                    Starsky & Hutch     6042
# 146                                    Steel Magnolias     4577
# 147                                            Stepmom     9617
# 148                                 Sweet Home Alabama    15582
# 149                                          Swordfish    11677
# 150                                        The Aviator    12966
# 151                                 The Bone Collector    10378
# 152                                The Bourne Identity     6037
# 153                               The Bourne Supremacy     2372
# 154                                 The Breakfast Club     6797
# 155               The Butterfly Effect: Director's Cut     9471
# 156                             The Day After Tomorrow    15205
# 157                           The Fast and the Furious     6844
# 158                                       The Fugitive    16384
# 159                             The General's Daughter    13462
# 160                                      The Godfather    12293
# 161                                     The Green Mile    16377
# 162                                    The Incredibles    10947
# 163                                    The Italian Job     4432
# 164                                   The Last Samurai     3624
# 165              The League of Extraordinary Gentlemen    10168
# 166                           The Manchurian Candidate    11314
# 167                                         The Matrix    14691
# 168                               The Matrix: Reloaded     3925
# 169                                  The Mummy Returns     5939
# 170                                       The Notebook    14103
# 171                                        The Patriot    14313
# 172                                        The Recruit     1428
# 173                                           The Rock    12317
# 174                               The Royal Tenenbaums     8782
# 175                                 The School of Rock    10583
# 176          The Shawshank Redemption: Special Edition    14550
# 177                           The Silence of the Lambs     2862
# 178                                    The Sixth Sense     4306
# 179                                 The Stepford Wives    14644
# 180                               The Sum of All Fears     3825
# 181                                       The Terminal    17355
# 182                                     The Terminator     6196
# 183                                 The Usual Suspects     6974
# 184                                       The Waterboy    14660
# 185                                The Wedding Planner     1145
# 186      There's Something About Mary: Special Edition     9592
# 187                                            Titanic    16879
# 188                                        Tomb Raider    14712
# 189                                            Top Gun     7624
# 190                                            Traffic    15394
# 191                                               Troy    13081
# 192                                            Twister    12470
# 193                                   Two Weeks Notice    13050
# 194                               Under the Tuscan Sun     5181
# 195                                        Van Helsing    15887
# 196                                    What Women Want     2152
# 197                                              X-Men    12785
# 198                                   X2: X-Men United      191
# 199                                    You've Got Mail    14574

# %%
#Test for different movie ratings

INPUT = {
    '1962': 5,#50 First Dates
    '571' : 5,#American Beauty
    '10359': 5, #Runaway Bride
    '11149': 5, #Maid in Manhattan
    '3938':5,#Shrek 2
    '15107':5,#Ocean's Eleven
    '14644': 5, #The Stepford Wives
#     '13728' : 5,
#     '11443' : 5, #harry potter
#     '2452': 4, #Lord of the Rings: The Fellowship of the Ring
#     '8687': 5, #Star wars
#     '17324':4, #Hitch,
#     '6037':4 #The Bourne Identity
#     '14691':4,
#     '2372':4,
#     '17627':5,
#     '5582':4
}

# %%
# #New user
new_user_rated_movies = INPUT.keys()
new_user_ratings = INPUT.values()
new_user_id = 99
new_user_id_list = [new_user_id]*len(new_user_rated_movies)
df_new_user = pd.DataFrame({'MovieID': new_user_rated_movies, 
                           'UserID' : new_user_id_list,
                           'Rating' : new_user_ratings })
df_new_user['MovieID'] = df_new_user['MovieID'].astype(int)
df_new_user['UserID'] = df_new_user['UserID'].astype(int)
total_movies = set(mv_ss['MovieID'].unique())
new_user_unrated_movies = list(total_movies.difference(set(df_new_user['MovieID'])))
df_new_user_mv_rec = pd.DataFrame({'MovieID' : new_user_unrated_movies,
                                  'UserID': [new_user_id]*len(new_user_unrated_movies)})

# %%
mv_ss = pd.concat([mv_ss, df_new_user])

# %%
# len(new_user_ids)

# %%
#Create pred ratings for other movies under the assumption that a rating for a given movie is 5

# new_user_ids = [i for i in range(100, 100 + len(movies_tot))]
# new_user_rating = [5]*len(new_user_ids)
# movie_id_new_user = list(movies_tot['MovieID'])

# df_new_users_rating = pd.DataFrame({'MovieID': movie_id_new_user,'UserID' : new_user_ids, 'Rating' : new_user_rating})

# %%
# df_new_users_rating

# %%
# mv_ss = pd.concat([mv_ss, df_new_users_rating])
# mv_ss.tail()

# %%
# len(mv_ss)

# %% [markdown]
# # Matrix Factorization

# %%
# The columns must correspond to user id, item id and ratings (in that order).
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(mv_ss[['UserID', 'MovieID', 'Rating']], reader)
algo = SVD(n_epochs = 20, lr_all = 0.002 , reg_all = 0.4)
algo.fit(data.build_full_trainset())

# %%
def predict_rating(row):
    return algo.predict(row['UserID'], row['MovieID'], r_ui=None, clip=True, verbose=False).est

# %%
df_new_user_mv_rec['pred_rating'] = df_new_user_mv_rec.apply(predict_rating, axis = 1)
df_new_user_mv_rec = df_new_user_mv_rec.merge(mv_info, left_on = 'MovieID', right_on = 'MovieID')
df_new_user_mv_rec = df_new_user_mv_rec.sort_values('pred_rating', ascending = False)

# %%
rec_mf_top_5 = df_new_user_mv_rec.reset_index(drop = True)[:5]

# %%
rec_mf_top_5
# Out:
#    MovieID  UserID  pred_rating  YearOfRelease                   Title
# 0       30      99     4.148587           2003  Something's Gotta Give
# 1      175      99     4.134830           1992          Reservoir Dogs
# 2      191      99     4.134347           2003        X2: X-Men United
# 3      457      99     4.125524           2004       Kill Bill: Vol. 2
# 4      313      99     4.124350           2000          Pay It Forward

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# # KNN item-item collaborative filtering

# %%
train, test = train_test_split(data, test_size=.2)
sim_options = {'name': 'msd',
               'min_support': 5,
               'user_based': False}
base1 = KNNBaseline(k=30,sim_options=sim_options)
base1.fit(train)
base1_preds = base1.test(test)
accuracy.rmse(base1_preds)
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4684
# 1.4683754545372827

# %%
def predict_rating(row):
    return base1.predict(row['UserID'], row['MovieID'], r_ui=None, clip=True, verbose=False).est

# %%
df_new_user_mv_rec['pred_rating'] = df_new_user_mv_rec.apply(predict_rating, axis = 1)
df_new_user_mv_rec = df_new_user_mv_rec.merge(mv_info, left_on = 'MovieID', right_on = 'MovieID')
df_new_user_mv_rec = df_new_user_mv_rec.sort_values('pred_rating', ascending = False)

# %%
pd.set_option('display.max_rows', None)
df_new_user_mv_rec.head()
# Out:
#      MovieID  UserID  pred_rating  YearOfRelease_x  \
# 80      9756      99          5.0             2002
# 98     11443      99          5.0             2002
# 1        175      99          5.0             1992
# 95      7745      99          5.0             1995
# 175    16384      99          5.0             1993
#
#                                      Title_x  YearOfRelease_y  \
# 80                                 Mr. Deeds             2002
# 98   Harry Potter and the Chamber of Secrets             2002
# 1                             Reservoir Dogs             1992
# 95                                 Apollo 13             1995
# 175                             The Fugitive             1993
#
#                                      Title_y
# 80                                 Mr. Deeds
# 98   Harry Potter and the Chamber of Secrets
# 1                             Reservoir Dogs
# 95                                 Apollo 13
# 175                             The Fugitive
